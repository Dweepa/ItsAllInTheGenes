# %%
from harmonizomeapi import Harmonizome, Entity

# %%
pid_dataset = Harmonizome.get(Entity.DATASET, name='PID pathways')
pid_dataset
# Out:
# {'association': 'protein-pathway associations from curated pathways',
#  'attributeGroup': 'functional term, phrase or reference',
#  'attributeType': 'pathway',
#  'datasetGroup': 'structural or functional annotations',
#  'description': 'sets of proteins participating in pathways',
#  'geneSets': [{'href': '/api/1.0/gene_set/a4b7+Integrin+signaling/PID+Pathways',
#    'name': 'a4b7 Integrin signaling/PID Pathways'},
#   {'href': '/api/1.0/gene_set/a6b1+and+a6b4+Integrin+signaling/PID+Pathways',
#    'name': 'a6b1 and a6b4 Integrin signaling/PID Pathways'},
#   {'href': '/api/1.0/gene_set/ALK1+pathway/PID+Pathways',
#    'name': 'ALK1 pathway/PID Pathways'},
#   {'href': '/api/1.0/gene_set/ALK1+signaling+events/PID+Pathways',
#    'name': 'ALK1 signaling events/PID Pathways'},
#   {'href': '/api/1.0/gene_set/ALK2+signaling+events/PID+Pathways',
#    'name': 'ALK2 signaling events/PID Pathways'},
#   {'href': '/api/1.0/gene_set/Alpha-synuclein+signaling/PID+Pathways',
# ...

# %%
entity_list = Harmonizome.get(Entity.GENE)
entity_list
# Out:
# {'count': 56720,
#  'entities': [{'href': '/api/1.0/gene/LOC105377913', 'symbol': 'LOC105377913'},
#   {'href': '/api/1.0/gene/LOC105377912', 'symbol': 'LOC105377912'},
#   {'href': '/api/1.0/gene/LOC105377911', 'symbol': 'LOC105377911'},
#   {'href': '/api/1.0/gene/PPATP2', 'symbol': 'PPATP2'},
#   {'href': '/api/1.0/gene/LOC102724608', 'symbol': 'LOC102724608'},
#   {'href': '/api/1.0/gene/LOC100506869', 'symbol': 'LOC100506869'},
#   {'href': '/api/1.0/gene/LOC105377915', 'symbol': 'LOC105377915'},
#   {'href': '/api/1.0/gene/LOC105377914', 'symbol': 'LOC105377914'},
#   {'href': '/api/1.0/gene/LOC102724604', 'symbol': 'LOC102724604'},
#   {'href': '/api/1.0/gene/LOC102724605', 'symbol': 'LOC102724605'},
#   {'href': '/api/1.0/gene/MTVR2', 'symbol': 'MTVR2'},
#   {'href': '/api/1.0/gene/LOC105377918', 'symbol': 'LOC105377918'},
#   {'href': '/api/1.0/gene/LOC100506860', 'symbol': 'LOC100506860'},
#   {'href': '/api/1.0/gene/LOC102724601', 'symbol': 'LOC102724601'},
# ...

# %%
more = Harmonizome.next(entity_list)
more
# Out:
# {'count': 56720,
#  'entities': [{'href': '/api/1.0/gene/RPS4XP1', 'symbol': 'RPS4XP1'},
#   {'href': '/api/1.0/gene/RPS4XP6', 'symbol': 'RPS4XP6'},
#   {'href': '/api/1.0/gene/RPS4XP7', 'symbol': 'RPS4XP7'},
#   {'href': '/api/1.0/gene/RPS4XP4', 'symbol': 'RPS4XP4'},
#   {'href': '/api/1.0/gene/BCL2A1', 'symbol': 'BCL2A1'},
#   {'href': '/api/1.0/gene/RPS4XP8', 'symbol': 'RPS4XP8'},
#   {'href': '/api/1.0/gene/RPS4XP9', 'symbol': 'RPS4XP9'},
#   {'href': '/api/1.0/gene/ITGAV', 'symbol': 'ITGAV'},
#   {'href': '/api/1.0/gene/SNRPCP6', 'symbol': 'SNRPCP6'},
#   {'href': '/api/1.0/gene/ITGAL', 'symbol': 'ITGAL'},
#   {'href': '/api/1.0/gene/ITGAM', 'symbol': 'ITGAM'},
#   {'href': '/api/1.0/gene/ITGAD', 'symbol': 'ITGAD'},
#   {'href': '/api/1.0/gene/ITGAE', 'symbol': 'ITGAE'},
#   {'href': '/api/1.0/gene/PRSM2', 'symbol': 'PRSM2'},
#   {'href': '/api/1.0/gene/LOC285804', 'symbol': 'LOC285804'},
#   {'href': '/api/1.0/gene/SEPT2P1', 'symbol': 'SEPT2P1'},
# ...

# %%
more = Harmonizome.next(more)
more
# Out:
# {'count': 56720,
#  'entities': [{'href': '/api/1.0/gene/LOC100631301', 'symbol': 'LOC100631301'},
#   {'href': '/api/1.0/gene/SIDT1', 'symbol': 'SIDT1'},
#   {'href': '/api/1.0/gene/SIDT2', 'symbol': 'SIDT2'},
#   {'href': '/api/1.0/gene/LOC100131242', 'symbol': 'LOC100131242'},
#   {'href': '/api/1.0/gene/LOC100131241', 'symbol': 'LOC100131241'},
#   {'href': '/api/1.0/gene/PISRT1', 'symbol': 'PISRT1'},
#   {'href': '/api/1.0/gene/LOC101927008', 'symbol': 'LOC101927008'},
#   {'href': '/api/1.0/gene/LOC283070', 'symbol': 'LOC283070'},
#   {'href': '/api/1.0/gene/LOC101927009', 'symbol': 'LOC101927009'},
#   {'href': '/api/1.0/gene/SAGE1', 'symbol': 'SAGE1'},
#   {'href': '/api/1.0/gene/LOC101927006', 'symbol': 'LOC101927006'},
#   {'href': '/api/1.0/gene/LOC105377719', 'symbol': 'LOC105377719'},
#   {'href': '/api/1.0/gene/LVCAT8', 'symbol': 'LVCAT8'},
#   {'href': '/api/1.0/gene/LOC101928748', 'symbol': 'LOC101928748'},
#   {'href': '/api/1.0/gene/LVCAT1', 'symbol': 'LVCAT1'},
# ...
