# %% [markdown]
# <img style="float: left;" src="https://cdn.pixabay.com/photo/2016/12/07/09/45/dna-1889085__340.jpg" width=10%> <h1> Application of AI to Discover Novel Binding of Small Molecules </h1>

# %% [markdown]
# ---------
# ### Sample Dataset for Testing Purposes
#
# ##### Here we create a sample dataset for two reason:
# - to get a better understanding of the structure of the data
# - test any sample code for validity
#
# ##### Structure of sample dataset:
# 1. A dataframe of consisting of 50 genes and 1020 profiles [50 x 1020]
# 2. Columns are a combination of drug, replicate, time, concentration, probe_location, cell type. For the purposes of this project only drug and replicate matters in terms of training. So the column name will be structed as
# "*drug + replicate id + unique characters that represent time, concentration, probe_location and cell type*"
# 3. 20 columns consist of control genes or 'control probes'. Columns are labelled control_x where x is a number from 1 to 20
# 3. Dataset consists of 25 drugs with 4 replicates and 10 combinations of time, concentration, probe_location and cell type
#
# | Feature      | Quantity | Represented By |
# | ----------- | ----------- | ----------- |
# | Drug      | 25       | Alphabets A-Y |
# | Replicate   | 4        | Numbers 1-4 |
# | Other features   | 10        | Random String of length 3 |
#
# ***R_3_xcv*** represents a profile of drug 'R', of replicate 3, with other features coresponding to 'xcv'
#
# ##### Construction of Sample Dataset

# %%
import random
import pandas as pd
import numpy as np

# %%
genes = ['gene'+str(a) for a in range(50)]
drugs = [chr(a) for a in range(65, 90)]
replicates = [str(a) for a in range(1, 5)]
other_features = set()

while len(other_features)!=10:
    rand_string = "". join([str(chr(int(random.random()*100)%26+97)) for a in range(3)])
    other_features.add(rand_string)

# %%
columns = ["control_"+str(a+1) for a in range(20)] + \
["_".join([a,b,c]) for a in drugs for b in replicates for c in other_features]

# %%
data = pd.DataFrame(np.random.randint(0,100,size=(50, 1020)), index=genes, columns=columns)
data.columns = columns
data.fillna(random.random(), inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-4ef0db046d62> in <module>()
# ----> 1 data = pd.DataFrame(np.random.rand(0,100,size=(50, 1020)), index=genes, columns=columns)
#       2 data.columns = columns
#       3 data.fillna(random.random(), inplace = True)
#
# TypeError: rand() got an unexpected keyword argument 'size'

# %%
data.head()
# Out:
#        control_1  control_2  control_3  control_4  control_5  control_6  \
# gene0         52         35          8         25         42         53
# gene1         51          3         16         32         12         27
# gene2         58         52         58         76         51         35
# gene3         63          2         10         23         48         70
# gene4         32         66         51         91         38          5
#
#        control_7  control_8  control_9  control_10   ...     Y_4_pig  Y_4_zqy  \
# gene0         97         61         15          61   ...          36       83
# gene1         12         29         89          50   ...          67        7
# gene2         55         56         22          21   ...          23       17
# gene3         87         11         58          38   ...          30       64
# gene4         49         48         77          77   ...          16       77
#
#        Y_4_zen  Y_4_fay  Y_4_fyv  Y_4_eiu  Y_4_vzn  Y_4_buf  Y_4_cgy  Y_4_kij
# gene0       99       76       74       28       76       24       84       59
# gene1       97       35        2       92       17       93       50       63
# gene2       98       79       92       28       58       84        8        9
# gene3       38        3        6       89       76       50       85       60
# gene4       66       66       53       73       58       49       29       57
#
# [5 rows x 1020 columns]
