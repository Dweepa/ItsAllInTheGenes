# %%
import pandas as pd
import numpy as np
import pickle
from typing import Optional, Union, Tuple
from cmapPy.pandasGEXpress.parse import parse
import numpy as np
import json
from collections import Counter
import sys
from numpy.core.multiarray import ndarray
import sys
import csv 
import requests 
import xml.etree.ElementTree as ET 
from xml.dom import minidom
# Out:
# /Users/dweepa/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Parsing the XML file

# %% [raw]
# tree = ET.parse('full_database.xml')
# root = tree.getroot()
# len(root)

# %% [raw]
# tree1 = ET.parse('test.xml')
# root1 = tree1.getroot()
# len(root1)

# %% [raw]
# def root2dict(root):
#     l = []
#
#     for i,idx in zip(root,range(len(root))):
#         row = dict()
#
#         try:
#             name = i.findall('{http://www.drugbank.ca}name')
#             row["name"] = name[0].text
#         except:
#             continue
#
#         atc = i.findall('{http://www.drugbank.ca}atc-codes')
#
#         #TODO: multiple <atc-code>
#         try:
#             for j in atc:
#                 code = j.findall("{http://www.drugbank.ca}atc-code")[0]
#                 row["atc-level5"] = code.attrib['code']
#                 level = code.findall("{http://www.drugbank.ca}level")
#                 count = 4
#                 for k in level:
#                     name = "atc-level"+str(count)
#                     row[name] = k.attrib['code']
#                     count=count-1
#         except:
#             pass
#
#         calc = i.findall('{http://www.drugbank.ca}calculated-properties')
#         for j in calc:
#             prop = j.findall('{http://www.drugbank.ca}property')
#             for k in prop:
#                 inchi = k.findall('{http://www.drugbank.ca}kind')
#                 for inch in inchi:
#                     if(inch.text=="InChIKey"):
#                         row["inchi_key"] = k.findall('{http://www.drugbank.ca}value')[0].text
#
#                     if(inch.text=="InChI"):
#                         row["inchi"] = k.findall('{http://www.drugbank.ca}value')[0].text
#
#                     if(inch.text=="SMILES"):
#                         row["smiles"] = k.findall('{http://www.drugbank.ca}value')[0].text
#
#         syn = i.findall('{http://www.drugbank.ca}synonyms/{http://www.drugbank.ca}synonym')
#         count=1
#         for s in syn:
#             if(s.attrib["language"]=='english'):
#                 name = "syn"+str(count)
#                 count+=1
#                 row[name] = s.text
#
#         pub = i.findall('{http://www.drugbank.ca}external-identifiers/{http://www.drugbank.ca}external-identifier')
#         for p in pub:
#             if(p.findall('{http://www.drugbank.ca}resource')[0].text == "PubChem Substance"):
#                 row["pubchem"]=p.findall('{http://www.drugbank.ca}identifier')[0].text
#         l.append(row)
#         sys.stdout.write("\r%d/%d"%(idx,len(root)))
#     return l

# %% [raw]
# d = root2dict(root)
# pd.DataFrame(d).to_csv("drugbank.csv",index=False)

# %% [markdown]
# ## Importing drugbank dataset

# %%
drugbank = pd.read_csv("drugbank.csv",low_memory=False)
drugbank = drugbank.dropna(how='all', axis='columns')
drugbank.head(2)
# Out:
#   atc-level1 atc-level2 atc-level3 atc-level4 atc-level5 inchi inchi_key  \
# 0          B        B01       B01A      B01AE    B01AE02   NaN       NaN
# 1          L        L01       L01X      L01XC    L01XC06   NaN       NaN
#
#         name     pubchem smiles ...  syn59 syn6 syn60 syn61 syn62 syn63 syn64  \
# 0  Lepirudin  46507011.0    NaN ...    NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 1  Cetuximab  46507042.0    NaN ...    NaN  NaN   NaN   NaN   NaN   NaN   NaN
#
#   syn7 syn8 syn9
# 0  NaN  NaN  NaN
# 1  NaN  NaN  NaN
#
# [2 rows x 74 columns]

# %%
p = pd.read_csv("../Data/GSE70138_Broad_LINCS_pert_info.txt",delimiter="\t")
p.canonical_smiles = p.canonical_smiles.str.upper()
p.head(2)
p.to_csv("metadata.csv",index=False)

# %%
X = pd.read_pickle("../Data/full")

# %%
# two different smiles for the same inchi_key
print(drugbank[drugbank.inchi_key=='QHMWCHQXCUNUAK-UHFFFAOYSA-N'].smiles.tolist()[0])
print(p[p.inchi_key=='QHMWCHQXCUNUAK-UHFFFAOYSA-N'].canonical_smiles.tolist()[0])
# Out:
# FC1=CC=C(C=C1)C(N1C=CN=C1)(C1=CC=CC=C1)C1=CC=CC=C1F
# FC1CCC(CC1)C(C1CCCCC1)(C1CCCCC1F)N1CCNC1

# %% [markdown]
# ## Get the atc codes via drugbank

# %%
def check_smile(smile1, smile2):
    smile_list1 = sorted([string for string in smile1.replace('=', '').replace(')', ' ').replace('(', ' ').split(' ') if string!=''])
    smile_list2 = sorted([string for string in smile2.replace('=', '').replace(')', ' ').replace('(', ' ').split(' ') if string!=''])
    
    return smile_list1 == smile_list2

# %%
li=[]
tar = np.unique(X.target)
unseen=0
for i in range(len(tar)):
    ret = dict()
    if(len(p[p.pert_id==tar[i]])==0):
        unseen+=1
        continue
    inchi_key = p[p.pert_id==tar[i]].inchi_key.tolist()[0]
    smiles = p[p.pert_id==tar[i]].canonical_smiles.tolist()[0]
    ret["inchi_key"]=inchi_key
    ret["smiles"]=smiles
#     print(inchi_key)
#     print(inchi_key, smiles)
    try:
        for l in range(1,6):
            if(inchi_key):
                ret["level"+str(l)] = drugbank[drugbank.inchi_key==inchi_key]["atc-level"+str(l)].tolist()[0]
#             if(smiles):
#                 print(smiles)
#                 ret["level"+str(l)] = drugbank[[check_smile(smile, smiles) for smile in drugbank.smiles]]["atc-level"+str(l)].tolist()[0]
        ret["name"] = drugbank[drugbank.inchi_key==inchi_key]["name"].tolist()[0]
    except:
        pass
    sys.stdout.write('\r%d/%d' % (i, len(tar)))
    li.append(ret)
    
print("\nUnseen perturbagen id's in metadata: ",unseen)
# Out:
# 2169/2170
# Unseen perturbagen id's in metadata:  0

# %%
# Instance of dictionary
li[0]
# Out:
# {'inchi_key': 'IETKPTYAGKZLKY-UHFFFAOYSA-N',
#  'level1': nan,
#  'level2': nan,
#  'level3': nan,
#  'level4': nan,
#  'level5': nan,
#  'name': 'Balaglitazone',
#  'smiles': 'CN1C(COC2CCC(CC3SC(=O)NC3=O)CC2)NC2CCCCC2C1=O'}

# %%
len(li)
# Out:
# 2170

# %% [markdown]
# ## Import the final dataset

# %%
# pd.DataFrame(li).to_csv("atc-codes.csv",index=False)
atc = pd.read_csv("atc-codes.csv")
atc.name=atc.name.str.lower()
atc.head(2)
# Out:
#                      inchi_key level1 level2 level3 level4   level5  \
# 0  IETKPTYAGKZLKY-UHFFFAOYSA-N    NaN    NaN    NaN    NaN      NaN
# 1  QHMWCHQXCUNUAK-UHFFFAOYSA-N      G    G01   G01A  G01AF  G01AF18
#
#             name                                         smiles
# 0  balaglitazone  CN1C(COC2CCC(CC3SC(=O)NC3=O)CC2)NC2CCCCC2C1=O
# 1   flutrimazole       FC1CCC(CC1)C(C1CCCCC1)(C1CCCCC1F)N1CCNC1

# %%
print(atc.shape)
atc.isnull().sum()
# Out:
# (2170, 9)
# inchi_key       0
# level1       1484
# level2       1484
# level3       1484
# level4       1484
# level5       1484
# name         1069
# smiles          0
# pert_id      1069
# dtype: int64

# %% [markdown]
# ## Import original ATC standalone dataset

# %%
atc_data = pd.read_excel("atc.xlsx")
atc_data.head(2)
# Out:
#                                             Class ID Preferred Label Synonyms  \
# 0  http://purl.bioontology.org/ontology/UATC/A03AX13       silicones      NaN
# 1  http://purl.bioontology.org/ontology/UATC/J01DB07     cefatrizine      NaN
#
#    Definitions  Obsolete       CUI  \
# 0          NaN     False  C0037114
# 1          NaN     False  C0007545
#
#                                       Semantic Types  \
# 0  http://purl.bioontology.org/ontology/STY/T109|...
# 1  http://purl.bioontology.org/ontology/STY/T195|...
#
#                                            Parents  ATC LEVEL Is Drug Class  \
# 0  http://purl.bioontology.org/ontology/UATC/A03AX        5.0           NaN
# 1  http://purl.bioontology.org/ontology/UATC/J01DB        5.0           NaN
#
#                          Semantic type UMLS property
# 0  http://purl.bioontology.org/ontology/STY/T109|...
# 1  http://purl.bioontology.org/ontology/STY/T195|...

# %%
atc_data = atc_data[['Preferred Label','Class ID']]
atc_data.rename(columns={'Preferred Label':"name",'Class ID':'atc' },inplace=True)

# %%
def make_level(c):
    atc_class = c.split('/')[-1]
    return atc_class

make_level("http://purl.bioontology.org/ontology/UATC/A03AX13")
# Out:
# 'A03AX13'

# %%
atc_data.atc = atc_data.atc.apply(make_level)
atc_data.to_csv("Final/atc.csv",index=False)
atc_data.head(2)
# Out:
#           name      atc
# 0    silicones  A03AX13
# 1  cefatrizine  J01DB07

# %% [markdown]
# ## Get pert_iname from pert_id

# %%
id_to_name = dict()
name_to_id = dict()
tar = np.unique(X.target)
count = 0
for i in range(len(tar)):
    a = p[p.pert_id==tar[i]].pert_iname
    if(a.to_string().split()[1]==''):
        a = a.to_string().split()[0]
    else:
        a = a.to_string().split()[1]
    a=a.translate({ord(')'): None})
    a=a.translate({ord(']'): None})
#     sys.stdout.write('\r%d/%d\t\t%s' % (i, len(tar),a))
#     print('%d/%d\t\t%s' % (i, len(tar),a))
    id_to_name[tar[i]]=a
    try:
        name_to_id[a]
        name_to_id[a]=name_to_id[a]+[tar[i]]
        count+=1
#         print(a,name_to_id[a])
    except:
        name_to_id[a]=[tar[i]]
#         print(a,name_to_id[a])

# %% [markdown]
# ### Creating 2 different dictionaries with name_to_id

# %%
name_to_id_single = dict()
name_to_id_multiple = dict()
for i in name_to_id.keys():
    if(len(name_to_id[i])>1):
        name_to_id_multiple[i]=name_to_id[i]
    elif(len(name_to_id[i])==1):
        name_to_id_single[i]=name_to_id[i]
        
len(name_to_id_multiple),len(name_to_id_single), len(name_to_id_multiple)+len(name_to_id_single)
# Out:
# (82, 1744, 1826)

# %%
print(len(name_to_id))
len(id_to_name)
# Out:
# 1826
# 2170

# %% [markdown]
# ## Get ATC codes from OG data

# %%
atc = atc[['name','level5']]
atc.rename(columns={"level5":"atc"},inplace=True)

# %%
meta  = pd.read_csv("Final/meta.csv")

# %%
print(atc.shape)
atc.head(2)
# Out:
# (2170, 2)
#             name      atc
# 0  balaglitazone      NaN
# 1   flutrimazole  G01AF18

# %%
len(np.unique(list(atc.name)))
# Out:
# 1101

# %%
print(meta.shape)
meta.head(2)
# Out:
# (2170, 4)
#                                               smiles  \
# 0                CCN(CC)CCCCN1C2CCCCC2OC2CCC(CL)CC12
# 1  CCCCCCCCCCCCCC(=O)O[C@@H]1[C@@H](C)[C@]2(O)[C@...
#
#                         name             id                    inchi_key
# 0                    10-DEBC  BRD-K70792160  GYBXAGDWMCJZJK-UHFFFAOYSA-N
# 1  phorbol-myristate-acetate  BRD-K68552125  PHEDXBVPIONUQT-RGYGYFBISA-N

# %%
pd.merge(atc_data,meta,left_on='name',right_on='name').shape
# Out:
# (1000, 5)

# %% [raw]
# # Unnamed: 0	inchi_key	level1	level2	level3	level4	level5	name	smiles
# li1=[]
# count=0
# for i in name_to_id.keys():
#     if(i in list(atc_data['Preferred Label'])):\
#         count+=1
#     atcdict = dict()
#     try:
#         atc_class = atc_data[atc_data['Preferred Label']==i]['Class ID'].tolist()[0].split('/')[-1]
#         print("%s\t%s\t%s"%(i , name_to_id[i], atc_class))
#         atcdict["name"] = i
#         atcdict["pert_id"] = name_to_id[i]
#         atcdict["level1"]=atc_class[0]
#         atcdict["level2"]=atc_class[0:2]
#         atcdict["level3"]=atc_class[0:3]
#         atcdict["level4"]=atc_class[0:5]
#         atcdict["level5"]=atc_class
#         atcdict['inchi_key']=''
#         atcdict['smiles']=''
#         li1.append(atcdict)
#     except Exception as e:
#         print(count)
#         pass

# %%
# 1 Instance of dict
len(li1)
# Out:
# 768

# %%
# atc = atc.drop(['Unnamed: 0'],axis=1)
atc['pert_id'] = atc.name
atc.pert_id = atc.pert_id.replace(name_to_id) 
atc.isnull().sum()
atc.head(2)
# Out:
#                      inchi_key level1 level2 level3 level4   level5  \
# 0  IETKPTYAGKZLKY-UHFFFAOYSA-N    NaN    NaN    NaN    NaN      NaN
# 1  QHMWCHQXCUNUAK-UHFFFAOYSA-N      G    G01   G01A  G01AF  G01AF18
#
#             name                                         smiles        pert_id
# 0  balaglitazone  CN1C(COC2CCC(CC3SC(=O)NC3=O)CC2)NC2CCCCC2C1=O  BRD-A00147595
# 1   flutrimazole       FC1CCC(CC1)C(C1CCCCC1)(C1CCCCC1F)N1CCNC1  BRD-A00218260

# %%
newatc = pd.DataFrame(li1)
newatc.isnull().sum()
# Out:
# inchi_key    0
# level1       0
# level2       0
# level3       0
# level4       0
# level5       0
# name         0
# pert_id      0
# smiles       0
# dtype: int64

# %% [markdown]
# # Append Data

# %%
wholeatc = newatc.append(atc)
wholeatc.isnull().sum()
# losartan 2
# fasudil 2
# nimesulide 2
# nicergoline 2
# tazarotene 2
# indoramin 2
# vandetanib 2
# naphazoline 2
# dequalinium 2
# moxonidine 2
# fluspirilene 2
# mebendazole 2
# furosemide 2
# enoxacin 2
# menadione 2
# crizotinib 2
# lonidamine 2
# ixazomib 2
# leflunomide 2
# albendazole 2
# decitabine 2
# cyclizine 2
# metformin 2
# sildenafil 2
# gliquidone 2
# moxisylyte 2
# dantrolene 2
# vorinostat 2
# tacrine 2
# nilotinib 2
# dinoprost 2
# triclabendazole 2
# dicoumarol 2
# binimetinib 2
# almitrine 2
# loratadine 2
# repaglinide 2
# rosuvastatin 2
# pimavanserin 2
# nizofenone 2
# candesartan 2
# nelarabine 2
# agomelatine 2
# riociguat 2
# darunavir 2
# pilocarpine 2
# tolbutamide 2
# zalcitabine 2
# dipyridamole 2
# allopurinol 2
# cabergoline 2
# edoxudine 2
# cediranib 2
# carbimazole 2
# isoniazid 2
# armodafinil 2
# piretanide 2
# fingolimod 2
# xaliproden 2
# trimetazidine 2
# pyrimethamine 2
# rucaparib 2
# aniracetam 2
# letrozole 2
# indacaterol 2
# ramipril 2
# pirenzepine 2
# trifluoperazine 2
# chlorpromazine 2
# bazedoxifene 2
# phentolamine 2
# nefazodone 2
# canagliflozin 2
# rotigotine 2
# nortriptyline 2
# amodiaquine 2
# betahistine 2
# nikethamide 2
# mercaptopurine 2
# felbinac 2
# triamterene 2
# doxorubicin 2
# lomitapide 2
# bexarotene 2
# oxandrolone 2
# safinamide 2
# zaleplon 2
# imatinib 2
# perindopril 2
# melperone 2
# cladribine 2
# apremilast 2
# lamotrigine 2
# buspirone 2
# ipriflavone 2
# tadalafil 2
# tamoxifen 2
# stavudine 2
# suvorexant 2
# diosmin 2
# ataluren 2
# probenecid 2
# trapidil 2
# darifenacin 2
# reserpine 2
# phentermine 2
# linagliptin 2
# itopride 2
# pirfenidone 2
# deferasirox 2
# pranlukast 2
# droperidol 2
# amiloride 2
# dihydroergocristine 2
# gestrinone 2
# melatonin 2
# mepyramine 2
# chlorpropamide 2
# theophylline 2
# rupatadine 2
# clonidine 2
# flumazenil 2
# felbamate 2
# hexachlorophene 2
# bosutinib 2
# nan 1069
# saracatinib 2
# 2938

# %%
len(atc.name) + len(newatc.name)
# Out:
# 2938

# %%
print(atc[atc.name=='saracatinib'])
print('\n',newatc[newatc.name=='saracatinib'],'\n')
print(wholeatc[wholeatc.name=='saracatinib'])
# Out:
#                         inchi_key level1 level2 level3 level4 level5  \
# 651   OUKYUETWWIPKQR-UHFFFAOYSA-N    NaN    NaN    NaN    NaN    NaN
# 1786  OUKYUETWWIPKQR-UHFFFAOYSA-N    NaN    NaN    NaN    NaN    NaN
#
#              name                                             smiles  \
# 651   saracatinib  CN1CCN(CCOC2CC(OC3CCOCC3)C3C(NC4C5OCOC5CCC4CL)...
# 1786  saracatinib  CN1CCN(CC1)CCOC2=CC(=C3C(=C2)N=CN=C3NC4=C(C=CC...
#
#             pert_id
# 651   BRD-U07805514
# 1786  BRD-U07805514
#
#  Empty DataFrame
# Columns: [inchi_key, level1, level2, level3, level4, level5, name, pert_id, smiles]
# Index: []
#
#                         inchi_key level1 level2 level3 level4 level5  \
# 651   OUKYUETWWIPKQR-UHFFFAOYSA-N    NaN    NaN    NaN    NaN    NaN
# 1786  OUKYUETWWIPKQR-UHFFFAOYSA-N    NaN    NaN    NaN    NaN    NaN
#
#              name        pert_id  \
# 651   saracatinib  BRD-U07805514
# 1786  saracatinib  BRD-U07805514
#
#                                                  smiles
# 651   CN1CCN(CCOC2CC(OC3CCOCC3)C3C(NC4C5OCOC5CCC4CL)...
# 1786  CN1CCN(CC1)CCOC2=CC(=C3C(=C2)N=CN=C3NC4=C(C=CC...

# %%
def common_member(a, b): 
    a_set = set(a) 
    b_set = set(b) 
    if (a_set & b_set): 
        print("Number of common elements: ",len(a_set & b_set))
        print("Total perts: ",len(set(a_set|b_set)))
        # returns all the perts in 2 sets
        return(set(a_set|b_set))
    else: 
        print("No common elements")  

all = list(common_member(atc.name.str.lower(),newatc.name))
all
# Out:
# Number of common elements:  605
# Total perts:  1264
# [nan,
#  'tetrahydropalmatine',
#  'ketoprofen',
#  'imexon',
#  'cinoxacin',
#  'amineptine',
#  'refametinib',
#  'deoxycholic acid',
#  'foretinib',
#  'darifenacin',
#  'flutrimazole',
#  'antipyrine',
#  'telmisartan',
#  'glycopyrronium',
#  'rosuvastatin',
#  'mazindol',
#  'fiacitabine',
#  'metformin',
#  'clinafloxacin',
#  'adenosine',
#  'vadimezan',
#  'alagebrium',
#  'bemegride',
#  'carisoprodol',
#  'tenidap',
#  'meclizine',
#  'naphazoline',
#  'sildenafil',
#  'fluoxetine',
#  '5-(2-phenylpyrazolo[1,5-a]pyridin-3-yl)-1h-pyrazolo[3,4-c]pyridazin-3-amine',
#  'pilocarpine',
#  'indacaterol',
#  'sulfisoxazole',
#  'bortezomib',
#  'thiocolchicoside',
#  'emapunil',
#  'dolasetron',
#  'iguratimod',
#  'novobiocin',
#  'indoximod',
#  'nizofenone',
#  'bupropion',
#  'tg100-115',
#  'alisertib',
#  'nafamostat',
#  'fluorometholone',
#  'acipimox',
#  'alpelisib',
#  'pranlukast',
#  'chlorprothixene',
#  'piroxicam',
#  'hymecromone',
#  'zileuton',
#  'diethylcarbamazine',
#  'iowh-032',
#  'lamivudine',
#  'palonosetron',
#  'raloxifene',
#  'gm6001',
#  'linagliptin',
#  'oxfendazole',
#  'luliconazole',
#  'cabergoline',
#  'emtricitabine',
#  'idebenone',
#  'epirubicin',
#  'lonafarnib',
#  'granisetron',
#  'tandutinib',
#  'otenabant',
#  'moxonidine',
#  'teriflunomide',
#  'gestrinone',
#  'timolol',
#  'maribavir',
#  'famotidine',
#  'jnj-38877605',
#  'protriptyline',
#  'rufinamide',
#  'sotrastaurin',
#  'dazoxiben',
#  'maprotiline',
#  'ebselen',
#  'etodolac',
#  'mebendazole',
#  'resiquimod',
#  'bexarotene',
#  'midodrine',
#  'gemifloxacin',
#  'cabazitaxel',
#  'propranolol',
#  'asenapine',
#  'siramesine',
#  'trovafloxacin',
#  'cabozantinib',
#  'clomipramine',
#  'oxybutynin',
#  'pracinostat',
#  'imatinib',
#  'bicalutamide',
#  'biperiden',
#  'metixene',
#  'phenformin',
#  'salvinorin a',
#  'pd-0325901',
#  'tipiracil',
#  'tirapazamine',
#  'ly-294002',
#  'gaboxadol',
#  'dipyridamole',
#  'citalopram',
#  'piclamilast',
#  'berzosertib',
#  'diethylstilbestrol',
#  'lidoflazine',
#  'oxymetazoline',
#  'berberine',
#  'avasimibe',
#  'thiabendazole',
#  'blonanserin',
#  'orantinib',
#  'simvastatin',
#  'dimethyl fumarate',
#  'indobufen',
#  'losartan',
#  'mubritinib',
#  'resatorvid',
#  'veliparib',
#  'bumetanide',
#  'capecitabine',
#  'pimasertib',
#  'pictilisib',
#  'defactinib',
#  'aliskiren',
#  'vandetanib',
#  'mianserin',
#  'fosfomycin',
#  'pilaralisib',
#  'biib021',
#  'raclopride',
#  'gliclazide',
#  'iniparib',
#  'delanzomib',
#  'cladribine',
#  'bucladesine',
#  'allopurinol',
#  'cyanocobalamin',
#  'indolylpropionic acid',
#  'pf-04217903',
#  'ambrisentan',
#  'leflunomide',
#  'olanzapine',
#  'pasireotide',
#  'ornidazole',
#  'oxandrolone',
#  'mepacrine',
#  'elesclomol',
#  '2-({5-chloro-2-[(2-methoxy-4-morpholin-4-ylphenyl)amino]pyrimidin-4-yl}amino)-n-methylbenzamide',
#  'xaliproden',
#  'vosaroxin',
#  'disopyramide',
#  'canertinib',
#  'bms-777607',
#  'r-428',
#  'tosedostat',
#  'ezogabine',
#  'ondansetron',
#  'ozagrel',
#  'dopamine',
#  '(2s)-1-(1h-indol-3-yl)-3-{[5-(3-methyl-1h-indazol-5-yl)pyridin-3-yl]oxy}propan-2-amine',
#  'tramiprosate',
#  'azd-1981',
#  'dabrafenib',
#  'mbx-2982',
#  'vicriviroc',
#  'staurosporine',
#  'lacosamide',
#  'omecamtiv mecarbil',
#  'cyclobenzaprine',
#  'pidotimod',
#  'metergoline',
#  'ixabepilone',
#  'molsidomine',
#  'ponatinib',
#  'moxisylyte',
#  'mequitazine',
#  'quizartinib',
#  'n-(5-{4-chloro-3-[(2-hydroxyethyl)sulfamoyl]phenyl}-4-methyl-1,3-thiazol-2-yl)acetamide',
#  'acebutolol',
#  'aripiprazole',
#  'levosalbutamol',
#  'pimobendan',
#  'talinolol',
#  'clofibrate',
#  'otilonium',
#  'nikethamide',
#  'varenicline',
#  'cariprazine',
#  'glasdegib',
#  'adapalene',
#  'cefoperazone',
#  'verteporfin',
#  'pomalidomide',
#  'pirenzepine',
#  'nevirapine',
#  'probenecid',
#  'tranilast',
#  'tolbutamide',
#  'piracetam',
#  'tirasemtiv',
#  'felodipine',
#  'formoterol',
#  'fenobam',
#  'diminazene',
#  'epirizole',
#  'formestane',
#  'mln8054',
#  'vinburnine',
#  'lerisetron',
#  'eptifibatide',
#  'mephentermine',
#  'pemirolast',
#  'mibampator',
#  'pentobarbital',
#  'brequinar',
#  'linopirdine',
#  'mycophenolic acid',
#  'mk-3207',
#  'cyproheptadine',
#  'physostigmine',
#  'lacidipine',
#  'linsitinib',
#  'ripasudil',
#  'ramatroban',
#  'indometacin',
#  'ibutilide',
#  'clonidine',
#  'colforsin',
#  'fingolimod',
#  'mercaptopurine',
#  'glibenclamide',
#  'onvansertib',
#  'acetazolamide',
#  'levocabastine',
#  'chloramphenicol',
#  'apixaban',
#  'ropinirole',
#  'dasatinib',
#  'lidocaine',
#  'oxybenzone',
#  'levamisole',
#  'golvatinib',
#  'lestaurtinib',
#  'penfluridol',
#  'dipraglurant',
#  'tamatinib',
#  'bitopertin',
#  'anastrozole',
#  'tg-100801',
#  'venetoclax',
#  'tazarotene',
#  'hydroxyurea',
#  'mericitabine',
#  'nitrendipine',
#  'tiagabine',
#  'trehalose',
#  'sulfasalazine',
#  'setiptiline',
#  'dutasteride',
#  'dactolisib',
#  'vemurafenib',
#  'rociletinib',
#  'docetaxel',
#  'levosimendan',
#  'fenticonazole',
#  'alprostadil',
#  'hydrocortisone',
#  'alizapride',
#  'orphenadrine',
#  'quisinostat',
#  'phenylbutazone',
#  'latanoprost',
#  'duvelisib',
#  'tivozanib',
#  'miglustat',
#  'ruxolitinib',
#  'naftopidil',
#  'letermovir',
#  'dihydroergocristine',
#  'tegobuvir',
#  'indoramin',
#  'armodafinil',
#  'bindarit',
#  'nepafenac',
#  'etomidate',
#  'medrysone',
#  'pevonedistat',
#  'ganetespib',
#  'genistein',
#  'lintitript',
#  'moricizine',
#  'chlorpropamide',
#  'aminoglutethimide',
#  'mk-5108',
#  'amantadine',
#  'anagrelide',
#  'empagliflozin',
#  'cutamesine',
#  'secnidazole',
#  'eugenol',
#  'bromocriptine',
#  'gsk-2636771',
#  'afuresertib',
#  'infigratinib',
#  'zonisamide',
#  'gemcitabine',
#  'thiomersal',
#  'alvocidib',
#  'amiloride',
#  'doxofylline',
#  'seviteronel',
#  'carbimazole',
#  'propafenone',
#  'methimazole',
#  'yohimbine',
#  'droperidol',
#  'indinavir',
#  'nortriptyline',
#  'acetaminophen',
#  'filgotinib',
#  'olaparib',
#  'vanoxerine',
#  'gsk-1292263',
#  'trimethoprim',
#  'calcitriol',
#  'senicapoc',
#  'propylthiouracil',
#  'dexamethasone',
#  'busulfan',
#  'sulbutiamine',
#  'pazopanib',
#  'dimethyl sulfoxide',
#  'raltegravir',
#  'idelalisib',
#  'erlotinib',
#  'tiabendazole',
#  'dorzolamide',
#  'bifemelane',
#  'aminocaproic acid',
#  'baricitinib',
#  'topiroxostat',
#  'px-12',
#  'enprofylline',
#  'mocetinostat',
#  'racecadotril',
#  'carprofen',
#  'proguanil',
#  'azelaic acid',
#  'brexpiprazole',
#  'alectinib',
#  'fasudil',
#  'sns-032',
#  'efaproxiral',
#  'fenoldopam',
#  'toremifene',
#  'benzylpenicillin',
#  'triethylenetetramine',
#  'sufentanil',
#  'prochlorperazine',
#  'praziquantel',
#  'acetylsalicylic acid',
#  'maraviroc',
#  'zardaverine',
#  'dilazep',
#  'fomepizole',
#  'tazobactam',
#  'tacrine',
#  'primidone',
#  'saracatinib',
#  'balapiravir',
#  'suvorexant',
#  'bupivacaine',
#  'voriconazole',
#  'linezolid',
#  'febuxostat',
#  'pindolol',
#  'dantrolene',
#  'salirasib',
#  'tedizolid',
#  'nilotinib',
#  'bambuterol',
#  'gatifloxacin',
#  'tamsulosin',
#  'afatinib',
#  'ganaxolone',
#  '2-iminobiotin',
#  'naproxen',
#  'tilarginine',
#  'volasertib',
#  'dacomitinib',
#  'ranolazine',
#  'mecamylamine',
#  'lersivirine',
#  'procainamide',
#  'azd-1480',
#  'sertraline',
#  'bms-906024',
#  'pantoprazole',
#  'clotrimazole',
#  'tanaproget',
#  'norfloxacin',
#  'tadalafil',
#  'rimegepant',
#  'chlormezanone',
#  'mirtazapine',
#  'altretamine',
#  'selinexor',
#  'niacin',
#  'mepyramine',
#  'belinostat',
#  'inositol',
#  'cefotetan',
#  'miltefosine',
#  'ticagrelor',
#  'galunisertib',
#  'zidovudine',
#  'ritonavir',
#  'clioquinol',
#  'lorazepam',
#  'carbachol',
#  'milrinone',
#  'dinoprost',
#  'ranitidine',
#  'carbamoylcholine',
#  'diclofenac',
#  'ramipril',
#  'betrixaban',
#  'trapidil',
#  'kx-01',
#  'chlorthalidone',
#  'nelarabine',
#  'balsalazide',
#  'ketoconazole',
#  'eplerenone',
#  'benzydamine',
#  'trimipramine',
#  'apremilast',
#  'nandrolone',
#  'mycophenolate mofetil',
#  'nimesulide',
#  'chromium picolinate',
#  'dofequidar',
#  'basimglurant',
#  'reboxetine',
#  'ecabet',
#  'nimodipine',
#  'prazosin',
#  'triamcinolone',
#  'ifenprodil',
#  'atomoxetine',
#  'drospirenone',
#  'azd-7762',
#  'trientine',
#  'flecainide',
#  'enoxolone',
#  'perindopril',
#  'dienogest',
#  'cinnarizine',
#  'pioglitazone',
#  'methyldopa',
#  'resveratrol',
#  'lonidamine',
#  'palbociclib',
#  'selegiline',
#  'sobetirome',
#  'crizotinib',
#  'hexachlorophene',
#  'minaprine',
#  'rg-4733',
#  'solifenacin',
#  'benazepril',
#  'imipramine',
#  'binimetinib',
#  'sumatriptan',
#  'nalbuphine',
#  'trametinib',
#  'doxepin',
#  'esmolol',
#  'clozapine',
#  'letrozole',
#  'oxypurinol',
#  'rolipram',
#  'tioguanine',
#  'simeprevir',
#  'dexloxiglumide',
#  'vidofludimus',
#  'cilengitide',
#  'varlitinib',
#  'enalapril',
#  'faropenem',
#  'aminosalicylic acid',
#  'rivaroxaban',
#  'ramelteon',
#  'castanospermine',
#  'pentamidine',
#  'betahistine',
#  'pf-477736',
#  'phenprocoumon',
#  'cx516',
#  'melatonin',
#  '5-deoxyflavanone',
#  'retigabine',
#  'repaglinide',
#  "5-fluoro-2'-deoxycytidine",
#  'quercetin',
#  'paroxetine',
#  'thalidomide',
#  'riociguat',
#  'doxapram',
#  'telbivudine',
#  'cariporide',
#  'isoniazid',
#  'furosemide',
#  'azd-5363',
#  'idalopirdine',
#  'tiludronic acid',
#  'saxagliptin',
#  'avagacestat',
#  'pyrimethamine',
#  'picotamide',
#  'selumetinib',
#  'isosorbide mononitrate',
#  'e-2012',
#  'bms-564929',
#  'clinofibrate',
#  'atorvastatin',
#  'rabusertib',
#  'relcovaptan',
#  'sulbactam',
#  'phenazone',
#  'isoconazole',
#  'metoprolol',
#  'vardenafil',
#  'venlafaxine',
#  'sitagliptin',
#  'amitriptyline',
#  'dosulepin',
#  'cep-37440',
#  'amcinonide',
#  'ivabradine',
#  'epinastine',
#  'flumatinib',
#  'ataluren',
#  'escitalopram',
#  'mk-0752',
#  'gliquidone',
#  'levonorgestrel',
#  'entecavir',
#  '7-ethyl-10-hydroxycamptothecin',
#  'vincamine',
#  'vismodegib',
#  'podofilox',
#  'n-6022',
#  'warfarin',
#  'apabetalone',
#  'aniracetam',
#  'cobimetinib',
#  '4-(4-chlorophenyl)-4-[4-(1h-pyrazol-4-yl)phenyl]piperidine',
#  'ivermectin',
#  'folic acid',
#  'estramustine phosphate',
#  'falnidamol',
#  'regorafenib',
#  'nicotinamide',
#  'moracizine',
#  'apitolisib',
#  'ribavirin',
#  'loperamide',
#  'etanidazole',
#  "2'-deoxycytidine",
#  'roxithromycin',
#  'loxoprofen',
#  'benfluorex',
#  'diacerein',
#  'merimepodib',
#  'fluphenazine',
#  'moxifloxacin',
#  'estradiol',
#  'cinepazide',
#  'trimetazidine',
#  'penciclovir',
#  'valproic acid',
#  'medetomidine',
#  'tepotinib',
#  'bisoprolol',
#  'apomorphine',
#  'troglitazone',
#  'duloxetine',
#  'glipizide',
#  'etacrynic acid',
#  'etoricoxib',
#  'chlorambucil',
#  'rasagiline',
#  'felbinac',
#  'rimonabant',
#  'azd-6482',
#  'metamizole',
#  'ledipasvir',
#  'cpi-613',
#  'ibudilast',
#  'temazepam',
#  'piretanide',
#  'vortioxetine',
#  'favipiravir',
#  'ketotifen',
#  'tolvaptan',
#  '2,6-dihydroanthra/1,9-cd/pyrazol-6-one',
#  'carbenoxolone',
#  'ly-2811376',
#  'guanethidine',
#  'alvelestat',
#  'emedastine',
#  'nesbuvir',
#  'lafutidine',
#  'grazoprevir',
#  'albendazole',
#  'azathioprine',
#  'sgx-523',
#  'etizolam',
#  '5-[(2-methyl-5-{[3-(trifluoromethyl)phenyl]carbamoyl}phenyl)amino]pyridine-3-carboxamide',
#  'azd-8055',
#  'elacridar',
#  'camptothecin',
#  'aminolevulinic acid',
#  'gimeracil',
#  'urapidil',
#  'clofazimine',
#  'dapsone',
#  'brivanib',
#  'oseltamivir acid',
#  'josamycin',
#  'butoconazole',
#  'tofacitinib',
#  'atenolol',
#  'seocalcitol',
#  'molindone',
#  'phenytoin',
#  'fluorouracil',
#  'ci-1040',
#  'ivacaftor',
#  'acetylcysteine',
#  'estriol',
#  'amlodipine',
#  'theophylline',
#  'desvenlafaxine',
#  'azd-4547',
#  'pimozide',
#  'paracetamol',
#  'pyrazinamide',
#  'fentiazac',
#  'sapitinib',
#  'temoporfin',
#  'd-serine',
#  'doxorubicin',
#  'carfilzomib',
#  'pritelivir',
#  'acyclovir',
#  'tetrabenazine',
#  'clofoctol',
#  'quinidine',
#  'pimecrolimus',
#  'amlexanox',
#  'sorafenib',
#  '6-o-benzylguanine',
#  'chlorphenamine',
#  'triamterene',
#  'mepivacaine',
#  'miconazole',
#  'argatroban',
#  '2-amino-5-bromo-6-phenylpyrimidin-4-ol',
#  'aprepitant',
#  'amoxapine',
#  'ipatasertib',
#  'gefitinib',
#  'tipifarnib',
#  'decitabine',
#  'miglitol',
#  'loratadine',
#  'chloroxine',
#  'amrinone',
#  'mirodenafil',
#  'thioridazine',
#  'flutamide',
#  'talazoparib',
#  'clomifene',
#  'azd-7687',
#  'saquinavir',
#  'gabapentin',
#  'danegaptide',
#  'meclofenamic acid',
#  'birinapant',
#  'phenylbutyric acid',
#  'torasemide',
#  'temozolomide',
#  'phentolamine',
#  'verapamil',
#  'fanapanel',
#  'rilpivirine',
#  'norethisterone',
#  'piperidolate',
#  'carvedilol',
#  'telcagepant',
#  'clarithromycin',
#  'rupatadine',
#  'fasiglifam',
#  'cts-1027',
#  'ubenimex',
#  'apocynin',
#  'benzthiazide',
#  'levobunolol',
#  'idasanutlin',
#  'tolnaftate',
#  'inosine',
#  'pralatrexate',
#  'mk-0893',
#  'acarbose',
#  'lofexidine',
#  'daporinad',
#  'resorcinol',
#  'm-chlorophenylpiperazine',
#  'rebamipide',
#  'n-{3-[(5-chloro-1h-pyrrolo[2,3-b]pyridin-3-yl)carbonyl]-2,4-difluorophenyl}propane-1-sulfonamide',
#  'enzastaurin',
#  'fulvestrant',
#  'aclidinium',
#  'epigallocatechin gallate',
#  'dacarbazine',
#  'colchicine',
#  'phenylephrine',
#  'candesartan',
#  'danazol',
#  'metolazone',
#  'everolimus',
#  'atovaquone',
#  'deferiprone',
#  'diosmin',
#  'gemfibrozil',
#  'dicloxacillin',
#  'propentofylline',
#  'pimavanserin',
#  'taselisib',
#  'taranabant',
#  'sirolimus',
#  'gdc-0152',
#  'pentoxifylline',
#  'amg-208',
#  'nefazodone',
#  'edetic acid',
#  'cytarabine',
#  'tioconazole',
#  'ulixertinib',
#  'semaxanib',
#  'edoxudine',
#  'dolutegravir',
#  'dexniguldipine',
#  'azithromycin',
#  'ofloxacin',
#  'rimantadine',
#  'lapatinib',
#  'n-omega-nitro-l-arginine methyl ester',
#  'tridolgosir',
#  'zstk-474',
#  'pf-03758309',
#  'testosterone',
#  'lisinopril',
#  'omeprazole',
#  'dextromethorphan',
#  'bosentan',
#  'rizatriptan',
#  'tacrolimus',
#  'carbamazepine',
#  'tobramycin',
#  'ibrutinib',
#  'tetrabromo-2-benzotriazole',
#  'mibefradil',
#  'reserpine',
#  'enzalutamide',
#  'sertaconazole',
#  'tak-733',
#  'theobromine',
#  'broxuridine',
#  'suprofen',
#  'sorbitol',
#  'methylprednisolone',
#  'radezolid',
#  'azelastine',
#  'masoprocol',
#  'progesterone',
#  'netupitant',
#  'indoprofen',
#  'piclidenoson',
#  'halcinonide',
#  'dolastatin 10',
#  'motesanib',
#  'nirogacestat',
#  'paclitaxel',
#  'sotalol',
#  'clobetasol',
#  'artesunate',
#  'carglumic acid',
#  'lamotrigine',
#  'cisatracurium',
#  'risperidone',
#  'zaleplon',
#  'sulfafurazole',
#  'agerafenib',
#  'sofalcone',
#  'clonazepam',
#  'methazolamide',
#  'isradipine',
#  'almorexant',
#  'ganciclovir',
#  'flumazenil',
#  'temsirolimus',
#  'indapamide',
#  'fluvoxamine',
#  'oxiconazole',
#  'metoclopramide',
#  'bavisant',
#  'cediranib',
#  'ly-2334737',
#  'reparixin',
#  'atrasentan',
#  '2-methoxyestradiol',
#  'telotristat',
#  'glyburide',
#  'dicoumarol',
#  'cp1-1189',
#  'hydroflumethiazide',
#  'cordycepin',
#  'omacetaxine mepesuccinate',
#  'valrubicin',
#  'ifosfamide',
#  'ph-797804',
#  'bendamustine',
#  'cholic acid',
#  'trifluridine',
#  'cevimeline',
#  'elvitegravir',
#  'n,n-dimethylarginine',
#  'regadenoson',
#  'cidoxepin',
#  'encenicline',
#  'tak-580',
#  'midostaurin',
#  '(4-amino-2-{[1-(methylsulfonyl)piperidin-4-yl]amino}pyrimidin-5-yl)(2,3-difluoro-6-methoxyphenyl)methanone',
#  'pf-04457845',
#  'naftidrofuryl',
#  'pf-03814735',
#  'lenvatinib',
#  'tasquinimod',
#  'rilmenidine',
#  'lodoxamide',
#  'ore-1001',
#  'mizolastine',
#  'amd-070',
#  'cyclizine',
#  'diethylpropion',
#  'lomerizine',
#  'amonafide',
#  'selisistat',
#  'itopride',
#  'quetiapine',
#  'riluzole',
#  'alvimopan',
#  'methoxsalen',
#  'finasteride',
#  'tauroursodeoxycholic acid',
#  'cp-724714',
#  'bezafibrate',
#  'arbutin',
#  'ethylmercurithiosalicylic acid',
#  'teneligliptin',
#  'ro-4987655',
#  'roquinimex',
#  'losmapimod',
#  'pravastatin',
#  'voglibose',
#  'vilazodone',
#  'nebivolol',
#  'etoposide',
#  'buspirone',
#  'atracurium',
#  'perampanel',
#  'aee-788',
#  'papaverine',
#  'nicergoline',
#  'clenbuterol',
#  'caffeine',
#  'labetalol',
#  'taladegib',
#  'indole-3-carbinol',
#  'entinostat',
#  'piketoprofen',
#  'raf-265',
#  'trazodone',
#  'ellagic acid',
#  "n-(4-methoxybenzyl)-n'-(5-nitro-1,3-thiazol-2-yl)urea",
#  'efatutazone',
#  'bendroflumethiazide',
#  'sb-705498',
#  'daunorubicin',
#  'bms-599626',
#  'anidulafungin',
#  'osi-027',
#  'triclosan',
#  '2-{[4-(1-methyl-4-pyridin-4-yl-1h-pyrazol-3-yl)phenoxy]methyl}quinoline',
#  'gibberellic acid',
#  'oxybuprocaine',
#  'cefdinir',
#  'navitoclax',
#  'masitinib',
#  'apilimod',
#  'alaproclate',
#  'mefloquine',
#  'zafirlukast',
#  'diazepam',
#  'quinapril',
#  'noscapine',
#  'darunavir',
#  'diflunisal',
#  'gsk-256066',
#  'gw842166',
#  'amodiaquine',
#  'lopinavir',
#  'tramadol',
#  'travoprost',
#  'cc-401',
#  'ciprofloxacin',
#  'imiquimod',
#  'edoxaban',
#  'estrone',
#  'meloxicam',
#  'apalutamide',
#  'tamoxifen',
#  'cianidanol',
#  'tiapride',
#  'oglemilast',
#  'mk-1775',
#  'methocarbamol',
#  'conivaptan',
#  'lesinurad',
#  'piribedil',
#  'palovarotene',
#  'talmapimod',
#  'trifluoperazine',
#  'amikacin',
#  'istaroxime',
#  'rucaparib',
#  'niclosamide',
#  'canagliflozin',
#  'timonacic',
#  'pinacidil',
#  'cisapride',
#  'roflumilast',
#  'z-160',
#  'zofenopril',
#  'neflamapimod',
#  'chloroquine',
#  'voxtalisib',
#  'seliciclib',
#  '8-cyclopentyl-1,3-dipropylxanthine',
#  'lenalidomide',
#  'mk-8245',
#  'trimebutine',
#  'nicardipine',
#  'felbamate',
#  'neostigmine',
#  'tacedinaline',
#  'moclobemide',
#  'cimetidine',
#  'zosuquidar',
#  'salsalate',
#  'tasisulam',
#  'neratinib',
#  'macitentan',
#  'enoxacin',
#  'eflornithine',
#  'ly-2090314',
#  'abacavir',
#  'griseofulvin',
#  'nefiracetam',
#  'ziprasidone',
#  'levocetirizine',
#  'zolpidem',
#  'romidepsin',
#  'rifabutin',
#  '(2s)-3-[4-(acetylamino)phenoxy]-2-hydroxy-2-methyl-n-[4-nitro-3-(trifluoromethyl)phenyl]propanamide',
#  'resminostat',
#  'deferasirox',
#  ...]

# %%
wholeatc.name = wholeatc.name.str.lower()

# %%
wholeatc.to_csv("wholeatc.csv",index=False)

# %%
name_to_id["balaglitazone"]
# Out:
# 'BRD-A00147595'

# %%
wholeatc.isnull().sum()
# Out:
# inchi_key       0
# level1       1484
# level2       1484
# level3       1484
# level4       1484
# level5       1484
# name         1069
# pert_id      1069
# smiles          0
# dtype: int64

# %%
df = pd.DataFrame()
n = list(Counter(wholeatc.name).keys())
for i in list(n):
    print(i, end=' ')
    tempdf = wholeatc[(wholeatc.name==i)]
    if len(tempdf)>1:
        test = wholeatc[(wholeatc.name==i) & (wholeatc.smiles!='')]
        print(">1 ",len(test))
        df = df.append(test)
    else:
        print("1 ",len(tempdf))
        df = df.append(tempdf)
# Out:
# flutrimazole >1  1
# biperiden >1  1
# drospirenone 1  1
# bupivacaine >1  1
# nitrendipine >1  1
# meptazinol >1  1
# lofexidine >1  1
# alizapride >1  1
# mepivacaine >1  1
# fulvestrant 1  1
# metoprolol >1  1
# maraviroc 1  1
# chlorphenamine >1  1
# bupropion >1  1
# docetaxel 1  1
# esmolol >1  1
# labetalol >1  1
# bopindolol >1  1
# racecadotril >1  1
# doxycycline 1  1
# flecainide >1  1
# verapamil >1  1
# argatroban 1  1
# tipranavir 1  1
# propranolol >1  1
# granisetron 1  1
# carvedilol >1  1
# (2s)-3-[4-(acetylamino)phenoxy]-2-hydroxy-2-methyl-n-[4-nitro-3-(trifluoromethyl)phenyl]propanamide 1  1
# isosorbide mononitrate 1  1
# tramiprosate 1  1
# n-6022 1  1
# edetic acid 1  1
# navitoclax 1  1
# dazoxiben 1  1
# ricolinostat 1  1
# mirodenafil 1  1
# azd-1981 1  1
# onvansertib 1  1
# avagacestat 1  1
# palovarotene 1  1
# quisinostat 1  1
# mln8054 1  1
# telatinib 1  1
# radezolid 1  1
# vicriviroc 1  1
# almorexant 1  1
# iowh-032 1  1
# novobiocin 1  1
# otilonium 1  1
# sobetirome 1  1
# neratinib 1  1
# refametinib 1  1
# linsitinib 1  1
# azd-7762 1  1
# pracinostat 1  1
# pf-04457845 1  1
# osi-027 1  1
# veliparib 1  1
# momelotinib 1  1
# spebrutinib 1  1
# alvocidib 1  1
# urea 1  1
# (2s)-1-(1h-indol-3-yl)-3-{[5-(3-methyl-1h-indazol-5-yl)pyridin-3-yl]oxy}propan-2-amine 1  1
# elacridar 1  1
# pimasertib 1  1
# gaboxadol 1  1
# tandutinib 1  1
# 7-ethyl-10-hydroxycamptothecin 1  1
# ezogabine 1  1
# cutamesine 1  1
# indiplon 1  1
# telcagepant 1  1
# apalutamide 1  1
# sacubitril 1  1
# 2'-deoxycytidine 1  1
# neflamapimod 1  1
# 6-o-benzylguanine 1  1
# tosedostat 1  1
# oglemilast 1  1
# mycophenolate mofetil 1  1
# gibberellic acid 1  1
# diminazene 1  1
# tirapazamine 1  1
# raf-265 1  1
# indoximod 1  1
# duvelisib 1  1
# oseltamivir acid 1  1
# quizartinib 1  1
# letermovir 1  1
# ly-2811376 1  1
# talazoparib 1  1
# istaroxime 1  1
# ph-797804 1  1
# alagebrium 1  1
# etanidazole 1  1
# brequinar 1  1
# pretomanid 1  1
# relcovaptan 1  1
# tezacaftor 1  1
# tetrabromo-2-benzotriazole 1  1
# quercetin 1  1
# netupitant 1  1
# tepotinib 1  1
# salirasib 1  1
# sapitinib 1  1
# azd-5363 1  1
# bms-564929 1  1
# vistusertib 1  1
# lopinavir 1  1
# goserelin 1  1
# tanaproget 1  1
# motesanib 1  1
# dimethyl sulfoxide 1  1

# %%
df.shape
# Out:
# (1264, 9)

# %%
cols = list(df)
cols.remove("smiles")
cols.remove("inchi_key")
df1 = df.dropna(how='any')
df1 = df1[cols]

# %%
df1.shape
# Out:
# (849, 7)

# %%
df.to_csv("cleaned-atc.csv",index=False)

# %%
pd.read_csv("cleaned-atc.csv").head(2)
# Out:
#   level1 level2 level3 level4   level5          name        pert_id
# 0      G    G01   G01A  G01AF  G01AF18  flutrimazole  BRD-A00218260
# 1      N    N04   N04A  N04AA  N04AA02     biperiden  BRD-A00546892

# %%
name_to_id_multiple
# Out:
# {'ACLY': ['BRDN0000734492',
#   'BRDN0000734551',
#   'BRDN0000734605',
#   'BRDN0000735220',
#   'BRDN0000735469',
#   'BRDN0000735471'],
#  'AKT1': ['BRDN0001054755',
#   'BRDN0001054783',
#   'BRDN0001054802',
#   'BRDN0001054816',
#   'BRDN0000563287'],
#  'EGFR': ['BRDN0001054761',
#   'BRDN0001054771',
#   'BRDN0001054880',
#   'BRDN0001054959',
#   'BRDN0001054960',
#   'BRDN0001055014',
#   'BRDN0001055063'],
#  'ERBB3': ['BRDN0001053762',
#   'BRDN0001053849',
#   'BRDN0001054042',
#   'BRDN0001054806',
#   'BRDN0001054864',
#   'BRDN0001055062',
#   'BRDN0001055121'],
#  'ERG': ['BRDN0001054763',
#   'BRDN0001054820',
#   'BRDN0001054853',
#   'BRDN0001054910',
#   'BRDN0001054940',
#   'BRDN0001054963',
#   'BRDN0001055025'],
#  'EX-527': ['BRD-A73908300', 'BRD-K76964878'],
#  'EXO1': ['BRDN0001054777',
#   'BRDN0001054849',
#   'BRDN0001054918',
#   'BRDN0001054989',
#   'BRDN0001054996',
#   'BRDN0001055133',
#   'BRDN0001055150'],
#  'FASN': ['BRDN0000734126',
#   'BRDN0000734202',
#   'BRDN0000734239',
#   'BRDN0000734265',
#   'BRDN0000734398',
#   'BRDN0000735497'],
#  'FN1': ['BRDN0000735601',
#   'BRDN0000735608',
#   'BRDN0000735615',
#   'BRDN0000735622',
#   'BRDN0000735625',
#   'BRDN0000735663'],
#  'GDC-0068': ['BRD-K43002773', 'BRD-K71480163'],
#  'GDC-0980': ['BRD-A18328003', 'BRD-K23228615'],
#  'GSK-1059615': ['BRD-K02708799', 'BRD-U24835547'],
#  'HDAC1': ['BRDN0000582685',
#   'BRDN0000733084',
#   'BRDN0000733107',
#   'BRDN0000733201',
#   'BRDN0000733270',
#   'BRDN0000733572'],
#  'HDAC2': ['BRDN0000582696',
#   'BRDN0000582953',
#   'BRDN0000733242',
#   'BRDN0000733424',
#   'BRDN0000733576',
#   'BRDN0000733740'],
#  'HDAC3': ['BRDN0000582717',
#   'BRDN0000733080',
#   'BRDN0000733447',
#   'BRDN0001053773',
#   'BRDN0001053789',
#   'BRDN0001053845'],
#  'IGF2BP2': ['BRDN0001054767',
#   'BRDN0001054770',
#   'BRDN0001054876',
#   'BRDN0001054891',
#   'BRDN0001055001',
#   'BRDN0001055155',
#   'BRDN0001055244'],
#  'INSM2': ['BRDN0000735955',
#   'BRDN0000736005',
#   'BRDN0000736013',
#   'BRDN0000736134',
#   'BRDN0000736141',
#   'BRDN0000736149'],
#  'ITGA11': ['BRDN0000735589',
#   'BRDN0000735605',
#   'BRDN0000735613',
#   'BRDN0000735617',
#   'BRDN0000735639',
#   'BRDN0000735642'],
#  'JUN': ['BRDN0000579719',
#   'BRDN0000579817',
#   'BRDN0000732954',
#   'BRDN0000732977',
#   'BRDN0000733153',
#   'BRDN0000735397'],
#  'KEAP1': ['BRDN0000735960',
#   'BRDN0000735972',
#   'BRDN0000736011',
#   'BRDN0000736023',
#   'BRDN0000736032',
#   'BRDN0000736148'],
#  'KIT': ['BRDN0001054760',
#   'BRDN0001054799',
#   'BRDN0001054857',
#   'BRDN0001054913',
#   'BRDN0001054936',
#   'BRDN0001054955',
#   'BRDN0001054971'],
#  'KRAS': ['BRDN0000563943',
#   'BRDN0001054852',
#   'BRDN0001054883',
#   'BRDN0001054889',
#   'BRDN0001054907',
#   'BRDN0001054949',
#   'BRDN0001054953'],
#  'KRT19': ['BRDN0000734148',
#   'BRDN0000734248',
#   'BRDN0000734501',
#   'BRDN0000734629',
#   'BRDN0000734845',
#   'BRDN0000735216'],
#  'LACZ': ['BRDN0000585417', 'BRDN0000585793', 'BRDN0000585800'],
#  'LUCIFERASE': ['BRDN0000585515',
#   'BRDN0000585533',
#   'BRDN0000585635',
#   'BRDN0000585768'],
#  'MAPKAPK2': ['BRDN0000735952',
#   'BRDN0000735953',
#   'BRDN0000735971',
#   'BRDN0000735986',
#   'BRDN0000736021',
#   'BRDN0000736207'],
#  'MAST4': ['BRDN0001054758',
#   'BRDN0001054792',
#   'BRDN0001054793',
#   'BRDN0001054824',
#   'BRDN0001054830',
#   'BRDN0001054831',
#   'BRDN0001054977'],
#  'MTOR': ['BRDN0000734053',
#   'BRDN0000734190',
#   'BRDN0000734476',
#   'BRDN0000734493',
#   'BRDN0000734637',
#   'BRDN0000734962',
#   'BRDN0000735218'],
#  'MTTP': ['BRDN0000734211',
#   'BRDN0000734247',
#   'BRDN0000734269',
#   'BRDN0000734431',
#   'BRDN0000734843',
#   'BRDN0000734854'],
#  'MYC': ['BRDN0000583095',
#   'BRDN0000583153',
#   'BRDN0000583166',
#   'BRDN0000986555',
#   'BRDN0000986590',
#   'BRDN0000986626',
#   'BRDN0000986636'],
#  'NF1': ['BRDN0000733304',
#   'BRDN0000733909',
#   'BRDN0000986728',
#   'BRDN0001053766',
#   'BRDN0001053786',
#   'BRDN0001053921'],
#  'OSI-027': ['BRD-K87124298', 'BRD-K94012289'],
#  'PFDN2': ['BRDN0001054780',
#   'BRDN0001054800',
#   'BRDN0001054827',
#   'BRDN0001054866',
#   'BRDN0001054888',
#   'BRDN0001054931',
#   'BRDN0001055117'],
#  'PIK3CA': ['BRDN0000562846',
#   'BRDN0000563123',
#   'BRDN0000563497',
#   'BRDN0000563548',
#   'BRDN0000563708',
#   'BRDN0000563793',
#   'BRDN0000563803',
#   'BRDN0001054759',
#   'BRDN0001054804',
#   'BRDN0001054861',
#   'BRDN0001054894',
#   'BRDN0001054935',
#   'BRDN0001054972',
#   'BRDN0001055065'],
#  'PLXNA1': ['BRDN0001054798',
#   'BRDN0001054828',
#   'BRDN0001054859',
#   'BRDN0001054905',
#   'BRDN0001054927',
#   'BRDN0001054957',
#   'BRDN0001055021'],
#  'PPP2R2C': ['BRDN0001054756',
#   'BRDN0001054775',
#   'BRDN0001054803',
#   'BRDN0001054881',
#   'BRDN0001054884',
#   'BRDN0001055059',
#   'BRDN0001055204'],
#  'PTP4A1': ['BRDN0001054769',
#   'BRDN0001054774',
#   'BRDN0001054846',
#   'BRDN0001054877',
#   'BRDN0001054941',
#   'BRDN0001055165'],
#  'RPS6': ['BRDN0001054787',
#   'BRDN0001054821',
#   'BRDN0001054840',
#   'BRDN0001054841',
#   'BRDN0001054851',
#   'BRDN0001054991',
#   'BRDN0001055080'],
#  'SMAD2': ['BRDN0000735580',
#   'BRDN0000735607',
#   'BRDN0000735632',
#   'BRDN0000735640',
#   'BRDN0000735656',
#   'BRDN0000735659'],
#  'SMAD3': ['BRDN0000735581',
#   'BRDN0000735614',
#   'BRDN0000735624',
#   'BRDN0000735627',
#   'BRDN0000735633',
#   'BRDN0000735647'],
#  'SMAD4': ['BRDN0000583152',
#   'BRDN0000583290',
#   'BRDN0001054781',
#   'BRDN0001054782',
#   'BRDN0001054817',
#   'BRDN0001055012',
#   'BRDN0001055134'],
#  'TGFBR1': ['BRDN0000735585',
#   'BRDN0000735586',
#   'BRDN0000735610',
#   'BRDN0000735641',
#   'BRDN0000735669',
#   'BRDN0000735754'],
#  'TGFBR2': ['BRDN0000735587',
#   'BRDN0000735623',
#   'BRDN0000735629',
#   'BRDN0000735667',
#   'BRDN0000735670',
#   'BRDN0000735701'],
#  'TINF2': ['BRDN0001054795',
#   'BRDN0001054873',
#   'BRDN0001054896',
#   'BRDN0001054920',
#   'BRDN0001054986',
#   'BRDN0001055038',
#   'BRDN0001055154'],
#  'TLK2': ['BRDN0001054765',
#   'BRDN0001054812',
#   'BRDN0001054823',
#   'BRDN0001054829',
#   'BRDN0001054844',
#   'BRDN0001055093',
#   'BRDN0001055094'],
#  'TP53': ['BRDN0000563703',
#   'BRDN0000734049',
#   'BRDN0000734793',
#   'BRDN0000986532',
#   'BRDN0000986557',
#   'BRDN0000986672',
#   'BRDN0000986732'],
#  'ZEB1': ['BRDN0000733114',
#   'BRDN0000733244',
#   'BRDN0000733441',
#   'BRDN0000733611',
#   'BRDN0000733888',
#   'BRDN0000733923'],
#  'afatinib': ['BRD-A58767537', 'BRD-K66175015'],
#  'azacitidine': ['BRD-K03406345', 'BRD-K55026842'],
#  'bortezomib': ['BRD-K50691590', 'BRD-K88510285'],
#  'brivanib': ['BRD-A21584801', 'BRD-K28428262'],
#  'curcumin': ['BRD-K07572174', 'BRD-K74148702'],
#  'dexamethasone': ['BRD-A35108200', 'BRD-A69951442'],
#  'etoposide': ['BRD-A33280134', 'BRD-K37798499'],
#  'everolimus': ['BRD-A25736793', 'BRD-K13154216', 'BRD-K13514097'],
#  'geldanamycin': ['BRD-A19500257', 'BRD-K11528507'],
#  'ibrutinib': ['BRD-A35869383', 'BRD-K70301465'],
#  'linsitinib': ['BRD-K07667918', 'BRD-K86118762'],
#  'pravastatin': ['BRD-A11170096', 'BRD-K31447894'],
#  'saracatinib': ['BRD-K19540840', 'BRD-U07805514'],
#  'semagacestat': ['BRD-K65592642', 'BRD-K81957469'],
#  'tacrolimus': ['BRD-A96754982', 'BRD-K69608737'],
#  'temsirolimus': ['BRD-A62025033', 'BRD-K42898655'],
#  'tofacitinib': ['BRD-K31283835', 'BRD-K36280065'],
#  'veliparib': ['BRD-K12737986', 'BRD-K87142802']}

# %%
drugbank.isnull().sum()
drugbank.shape
# Out:
# (13339, 74)
